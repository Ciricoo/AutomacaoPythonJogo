# %%
# !pip install pyautogui
# !pip install pyperclip
# Out:
# Requirement already satisfied: pyautogui in c:\users\joao_cirico\anaconda3\lib\site-packages (0.9.53)
# Requirement already satisfied: PyTweening>=1.0.1 in c:\users\joao_cirico\anaconda3\lib\site-packages (from pyautogui) (1.0.5)
# Requirement already satisfied: pyscreeze>=0.1.21 in c:\users\joao_cirico\anaconda3\lib\site-packages (from pyautogui) (0.1.28)
# Requirement already satisfied: mouseinfo in c:\users\joao_cirico\anaconda3\lib\site-packages (from pyautogui) (0.1.3)
# Requirement already satisfied: pygetwindow>=0.0.5 in c:\users\joao_cirico\anaconda3\lib\site-packages (from pyautogui) (0.0.9)
# Requirement already satisfied: pymsgbox in c:\users\joao_cirico\anaconda3\lib\site-packages (from pyautogui) (1.0.9)
# Requirement already satisfied: pyrect in c:\users\joao_cirico\anaconda3\lib\site-packages (from pygetwindow>=0.0.5->pyautogui) (0.2.0)
# Requirement already satisfied: pyperclip in c:\users\joao_cirico\anaconda3\lib\site-packages (from mouseinfo->pyautogui) (1.8.2)
# Requirement already satisfied: pyperclip in c:\users\joao_cirico\anaconda3\lib\site-packages (1.8.2)

# %%
import pyautogui
import pyperclip
import time

pyautogui.PAUSE = 1

pyautogui.hotkey("ctrl", "t")
pyperclip.copy("https://drive.google.com/drive/my-drive")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")

time.sleep(5)

pyautogui.click(x=437, y=568, clicks = 2 )
time.sleep(2)

pyautogui.click(x=414, y=312)
pyautogui.click(x=503, y=164)
time.sleep(3)


pyautogui.hotkey("ctrl", "t")
pyperclip.copy("https://mail.google.com/mail/u/0/?tab=rm&ogbl#inbox")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")
time.sleep(3)

pyautogui.click(x=185, y=177)
time.sleep(3)

pyautogui.write("joao_cirico@estudante.sesisenai.org.br")
pyautogui.press("tab")

pyautogui.press("tab")
pyperclip.copy("Relatório de Vendas")
pyautogui.hotkey("ctrl","v")
pyautogui.press("tab")


texto = f"""
Prezados, Bom dia!

O faturamento de ontem foi de: R${faturamento:,.2f}
A quantidade de produtos foi de: {quantidade:,}

Abs
João Vitor"""

pyperclip.copy(texto)
pyautogui.hotkey("ctrl","v")
time.sleep(2)

pyautogui.click(x=850, y=635)
time.sleep(2)

# %%
import pandas as pd

tabela = pd.read_excel(r"C://Users/joao_cirico/Downloads/Vendas - Dez.xlsx")
display(tabela)
faturamento = tabela["Valor Final"].sum()
quantidade = tabela["Quantidade"].sum()
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# 0              5             114          570
# 1              1             269          269
# 2              2             363          726
# 3              1             250          250
# 4              3              92          276
# ...          ...             ...          ...
# 7084           2             102          204
# 7085           4             270         1080
# 7086           1              87           87
# 7087           1             108          108
# 7088           2             133          266
#
# [7089 rows x 7 columns]

# %%
import pyautogui
import pyperclip
import time

pyautogui.PAUSE = 1

pyautogui.hotkey("ctrl", "t")
pyperclip.copy("https://mail.google.com/mail/u/0/?tab=rm&ogbl#inbox")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")
time.sleep(3)

pyautogui.click(x=185, y=177)
time.sleep(5)

pyautogui.write("joao_cirico@estudante.sesisenai.org.br")
pyautogui.press("tab")

pyautogui.press("tab")
pyperclip.copy("Relatório de Vendas")
pyautogui.hotkey("ctrl","v")
pyautogui.press("tab")


texto = f"""
Prezados, Bom dia!

O faturamento de ontem foi de: R${faturamento:,.2f}
A quantidade de produtos foi de: {quantidade:,}

Abs
João Vitor"""

pyperclip.copy(texto)
pyautogui.hotkey("ctrl","v")
time.sleep(2)

pyautogui.click(x=850, y=635)
time.sleep(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\JOAO_C~1\AppData\Local\Temp/ipykernel_21276/48256915.py in <module>
#      26 Prezados, Bom dia!
#      27
# ---> 28 O faturamento de ontem foi de: R${faturamento:,.2f}
#      29 A quantidade de produtos foi de: {quantidade:,}
#      30
#
# NameError: name 'faturamento' is not defined

# %%
import pyautogui
import time

time.sleep(4)
pyautogui.position()
# Out:
# Point(x=854, y=688)

# %%
import pyautogui
import pyperclip
import time

pyautogui.PAUSE = 1

pyautogui.hotkey("ctrl", "t")
pyperclip.copy("https://www.friv.com/")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")
time.sleep(2)
pyautogui.click(x=319, y=54)
pyperclip.copy(r"https://www.friv.com/z/games/avoidmissiles/game.html")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")
time.sleep(7)
x = 0

pyautogui.click(x=663, y=240)
time.sleep(2)
pyautogui.click(x=676, y=594)
time.sleep(2)
pyautogui.click(x=676, y=594)
time.sleep(2)
pyautogui.click(x=676, y=522)
time.sleep(2)


while( x < 5):
	pyautogui.click(x=50, y=90)
	time.sleep(1)
	pyautogui.click(x=368, y=701)
	time.sleep(1)
	pyautogui.click(x=1286, y=598)
	time.sleep(1)
	pyautogui.click(x=940, y=213)
	time.sleep(1)
	x = x + 1
    

time.sleep(3)
pyautogui.click()
time.sleep(1)
pyautogui.moveTo(317, 132)
time.sleep(1)
pyautogui.hotkey("shift","win","s")
time.sleep(1)
pyautogui.dragTo(1052, 673, 3)
time.sleep(3)

pyautogui.hotkey("ctrl", "t")
time.sleep(1)
pyautogui.write("https://mail.google.com/mail/u/0/?tab=rm&ogbl#inbox")
pyautogui.press("enter")
time.sleep(3)

pyautogui.click(x=185, y=177)
time.sleep(5)

pyautogui.write("joao_cirico@estudante.sesisenai.org.br")
pyautogui.press("tab")

pyautogui.press("tab")
time.sleep(1)
pyautogui.write("Record Avoid Missiles")
pyautogui.press("tab")
time.sleep(2)
pyautogui.hotkey("ctrl", "v")
time.sleep(3)
pyautogui.hotkey("ctrl","enter")

# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\joao_cirico\anaconda3\lib\site-packages (4.9.1)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in c:\users\joao_cirico\anaconda3\lib\site-packages (from selenium) (1.26.7)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\joao_cirico\anaconda3\lib\site-packages (from selenium) (0.10.2)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\joao_cirico\anaconda3\lib\site-packages (from selenium) (2021.10.8)
# Requirement already satisfied: trio~=0.17 in c:\users\joao_cirico\anaconda3\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\joao_cirico\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.2.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\joao_cirico\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.14.6)
# Requirement already satisfied: outcome in c:\users\joao_cirico\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sortedcontainers in c:\users\joao_cirico\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: sniffio in c:\users\joao_cirico\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\joao_cirico\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.1.1)
# Requirement already satisfied: idna in c:\users\joao_cirico\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.2)
# Requirement already satisfied: async-generator>=1.9 in c:\users\joao_cirico\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: pycparser in c:\users\joao_cirico\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.20)
# Requirement already satisfied: wsproto>=0.14 in c:\users\joao_cirico\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\joao_cirico\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\joao_cirico\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

navegador = webdriver.Chrome()
navegador.get("https://www.google.com/")
navegador.find_element(By.XPATH,'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/textarea').send_keys("cotação dólar")
navegador.find_element(By.XPATH,'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/textarea').send_keys(Keys.ENTER)
cotacao_dolar = navegador.find_element(By.XPATH,'//*[@id="knowledge-currency__updatable-data-column"]/div[1]/div[2]/span[1]').get_attribute("data-value")
print(cotacao_dolar)

navegador.get("https://www.google.com/")
navegador.find_element(By.XPATH,'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/textarea').send_keys("cotação euro")
navegador.find_element(By.XPATH,'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/textarea').send_keys(Keys.ENTER)
cotacao_euro = navegador.find_element(By.XPATH,'//*[@id="knowledge-currency__updatable-data-column"]/div[1]/div[2]/span[1]').get_attribute("data-value")
print(cotacao_euro)

navegador.get("https://www.melhorcambio.com/ouro-hoje")
cotacao_ouro = navegador.find_element(By.XPATH, '//*[@id="comercial"]').get_attribute("value")
cotacao_ouro = cotacao_ouro.replace(",", ".")
print(cotacao_ouro)

navegador.quit()

import pandas as pd

tabela = pd.read_excel(r"C:\Users\Joao_cirico\Desktop\Projeto Fabiano\Produtos.xlsx")
display(tabela)


tabela.loc[tabela["Moeda"] == "Dólar", "Cotação"] = float(cotacao_dolar)
tabela.loc[tabela["Moeda"] == "Euro", "Cotação"] = float(cotacao_euro)
tabela.loc[tabela["Moeda"] == "Ouro", "Cotação"] = float(cotacao_ouro)
 

tabela["Preço de Compra"] = tabela["Preço Original"] * tabela["Cotação"]
tabela["Preço de Venda"] = tabela["Preço de Compra"] * tabela["Margem"]
display(tabela)

tabela.to_excel("Produtos Novo.xlsx", index=False)
# Out:
# 4.9674
# 5.421867426
# 323.98
#          Produtos  Preço Original  Moeda  Cotação  Preço de Compra  Margem  \
# 0    Câmera Canon          999.99  Dólar        5          4999.95    1.40
# 1   Carro Renault         4500.00   Euro        6         27000.00    2.00
# 2   Notebook Dell          899.99  Dólar        5          4499.95    1.70
# 3          IPhone          799.00  Dólar        5          3995.00    1.70
# 4      Carro Fiat         3000.00   Euro        6         18000.00    1.90
# 5  Celular Xiaomi          480.48  Dólar        5          2402.40    2.00
# 6        Joia 20g           20.00   Ouro      350          7000.00    1.15
#
#    Preço de Venda
# 0        6999.930
# 1       54000.000
# 2        7649.915
# 3        6791.500
# 4       34200.000
# 5        4804.800
# 6        8050.000
#          Produtos  Preço Original  Moeda     Cotação  Preço de Compra  Margem  \
# 0    Câmera Canon          999.99  Dólar    4.967400      4967.350326    1.40
# 1   Carro Renault         4500.00   Euro    5.421867     24398.403417    2.00
# 2   Notebook Dell          899.99  Dólar    4.967400      4470.610326    1.70
# 3          IPhone          799.00  Dólar    4.967400      3968.952600    1.70
# 4      Carro Fiat         3000.00   Euro    5.421867     16265.602278    1.90
# 5  Celular Xiaomi          480.48  Dólar    4.967400      2386.736352    2.00
# 6        Joia 20g           20.00   Ouro  323.980000      6479.600000    1.15
#
#    Preço de Venda
# 0     6954.290456
# 1    48796.806834
# 2     7600.037554
# 3     6747.219420
# 4    30904.644328
# 5     4773.472704
# 6     7451.540000

# %%
pyautogui.hotkey("shift","win","s")
time.sleep(1)
pyautogui.click(x=317, y=132)
time.sleep(1)
pyautogui.dragTo(1052, 673)
pyautogui.click()
time.sleep(3)

# %%
pyautogui.dragTo(x=1052, y=673)

# %%
pyautogui.click()
time.sleep(1)
pyautogui.moveTo(317, 132)
time.sleep(1)
pyautogui.hotkey("shift","win","s")
time.sleep(1)
pyautogui.dragTo(1052, 673, 3)
time.sleep(3)
